# %% [markdown]
# ## Importing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris

# %% [markdown]
# ## Reading in data

# %%
TanzaniaMobMon = pd.read_csv('C:/Users/Mc Camel RT .LAPTOP-6N3UDB08/Downloads/training.csv')
TanzaniaMobMon.columns
TanzaniaMobMon.head(5)
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %% [markdown]
# ## 1. Examine the dataset.
# ## Are there any missing observations or columns where the data do not seem valid?

# %%
print("The number of missing values are:",TanzaniaMobMon.isnull().sum().sum())
# Out:
# The number of missing values are: 0

# %% [markdown]
# ## 2. Get basic descriptive statistics for the dataset.

# %%
    assign_gender ={1:'Male',2:'Female'}

    assign_marital_status ={
    1:'Married',
    2:'Divorced',
    3:'Widowed',
    4:'Single/never_married'
    }

assign_land ={
    1:'owns_land',
    2:'jiont_ownership',
    3:'household_member_owns',
    4:'rented',
    5:'does_not_own',
    6:'does_not_know'
    }

assign_mm_classification ={
    0:'no_mobile_money',
    1:'other_finacial_service',
    2:'mobile_money_only',
    3:'mobile_money_and_other'
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-69533d662ffe> in <module>
#      24 }
#      25
# ---> 26 data.gender = data.gender.map(assign_gender)
#      27 data.marital_status = data.marital_status.map(assign_marital_status)
#      28 data.mobile_money_classification = data.mobile_money_classification.map(assign_mm_classification)
#
# NameError: name 'data' is not defined

# %%
TanzaniaMobMon.describe()
#count = TanzaniaMobMon['ID'].count()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
#Describing the size of the dataset:
print("In these results, you have", count, "observations:")
# Out:
# In these results, you have 7094 observations:

# %%
#Describe the center of your data
#Mean: 
print("The mean age is",TanzaniaMobMon["Q1"].mean())
    
#    Median:
 #       
print("The median age is",TanzaniaMobMon["Q1"].median())
# Out:
# The mean age is 38.23949816746546
# The median age is 35.0

# %%
#Describe the spread of your data
#TanzaniaMobMon["Q1"].hist()
#plt.boxplot(TanzaniaMobMon["Q1"])
#plt.show()


# A histogram
fig, axes = plt.subplots(1,2, figsize=(12,4))

axes[0].hist(TanzaniaMobMon['Q1'])
axes[0].set_title("Default histogram")
axes[0].set_xlim((min(TanzaniaMobMon['Q1']), max(TanzaniaMobMon['Q1'])))

axes[1].boxplot(TanzaniaMobMon["Q1"])
axes[1].set_title("Boxplot")
axes[1].set_xlim((min(TanzaniaMobMon["Q1"]), max(TanzaniaMobMon["Q1"])));

# %% [markdown]
# #Histogram:
# #the distribution of the variable age,
#
# #Boxplot:
#  #Max: 100
#  #Min: 16
#  The boxplot is skewed to the left

# %% [markdown]
# ## 3. Create appropriate graphs to visually represent the relationship between financial services accessed (non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income

# %%
# financial services accessed vs age
import matplotlib.pyplot as plt

clases = TanzaniaMobMon["mobile_money_classification"]
agecl = TanzaniaMobMon["Q1"]

import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("clases")
g = sns.pairplot(iris)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-92-4daf3f71ad12> in <module>
#       6
#       7 import seaborn as sns; sns.set(style="ticks", color_codes=True)
# ----> 8 iris = sns.load_dataset("clases")
#       9 g = sns.pairplot(iris)
#
# ~\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...
